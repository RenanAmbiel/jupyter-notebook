# %%
import os
import ee
import geemap

# %%
Map = geemap.Map()

# Add Earth Engine datasets
landcover = ee.Image("ESA/GLOBCOVER_L4_200901_200912_V2_3").select('landcover')


# Add Earth Engine layers to Map
Map.addLayer(landcover, {}, 'Land cover')
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=UFkk-zFIDScS3t7rG2NQ5Q79eVDJdWwxx3FzEq7uKNQ&tc=awDbNpImiJtlZhYLbm40ognyUL-bwIIrG_XJ9a_HURE&cc=API_87Cy7rZ72mDmsIWI6GUUGvxcGAMMGyVv24C1-ec
#
# The authorization workflow will generate a code, which you should paste in the box below.
